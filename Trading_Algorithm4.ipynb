# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5.QAxContainer import *
from PyQt5.QtCore import *
import time
import pandas as pd
import sqlite3

TR_REQ_TIME_INTERVAL = 0.2

class Kiwoom(QAxWidget):
    def __init__(self):
        super().__init__()
        self._create_kiwoom_instance()
        self._set_signal_slots()

    def _create_kiwoom_instance(self):
        self.setControl("KHOPENAPI.KHOpenAPICtrl.1")

    def _set_signal_slots(self):
        self.OnEventConnect.connect(self._event_connect)
        self.OnReceiveTrData.connect(self._receive_tr_data)

    def comm_connect(self):
        self.dynamicCall("CommConnect()")
        self.login_event_loop = QEventLoop()
        self.login_event_loop.exec_()

    def _event_connect(self, err_code):
        if err_code == 0:
            print("connected")
        else:
            print("disconnected")

        self.login_event_loop.exit()

    def get_code_list_by_market(self, market):
        code_list = self.dynamicCall("GetCodeListByMarket(QString)", market)
        code_list = code_list.split(';')
        return code_list[:-1]

    def get_master_code_name(self, code):
        code_name = self.dynamicCall("GetMasterCodeName(QString)", code)
        return code_name

    def set_input_value(self, id, value):
        self.dynamicCall("SetInputValue(QString, QString)", id, value)

    def comm_rq_data(self, rqname, trcode, next, screen_no):
        self.dynamicCall("CommRqData(QString, QString, int, QString", rqname, trcode, next, screen_no)
        self.tr_event_loop = QEventLoop()
        self.tr_event_loop.exec_()

    def _comm_get_data(self, code, real_type, field_name, index, item_name):
        ret = self.dynamicCall("CommGetData(QString, QString, QString, int, QString", code,
                               real_type, field_name, index, item_name)
        return ret.strip()

    def _get_repeat_cnt(self, trcode, rqname):
        ret = self.dynamicCall("GetRepeatCnt(QString, QString)", trcode, rqname)
        return ret

    def _receive_tr_data(self, screen_no, rqname, trcode, record_name, next, unused1, unused2, unused3, unused4):
        if next == '2':
            self.remained_data = True
        else:
            self.remained_data = False

        if rqname == "opt10081_req":
            self._opt10081(rqname, trcode)

        try:
            self.tr_event_loop.exit()
        except AttributeError:
            pass

    def _opt10081(self, rqname, trcode):
        data_cnt = self._get_repeat_cnt(trcode, rqname)

        for i in range(data_cnt):
            date = self._comm_get_data(trcode, "", rqname, i, "일자")
            open = self._comm_get_data(trcode, "", rqname, i, "시가")
            high = self._comm_get_data(trcode, "", rqname, i, "고가")
            low = self._comm_get_data(trcode, "", rqname, i, "저가")
            close = self._comm_get_data(trcode, "", rqname, i, "현재가")
            volume = self._comm_get_data(trcode, "", rqname, i, "거래량")

            self.ohlcv['date'].append(date)
            self.ohlcv['open'].append(int(open))
            self.ohlcv['high'].append(int(high))
            self.ohlcv['low'].append(int(low))
            self.ohlcv['close'].append(int(close))
            self.ohlcv['volume'].append(int(volume))

if __name__ == "__main__":
    app = QApplication(sys.argv)
    kiwoom = Kiwoom()
    kiwoom.comm_connect()

    kiwoom.ohlcv = {'date': [], 'open': [], 'high': [], 'low': [], 'close': [], 'volume': []}

    # opt10081 TR 요청
    kiwoom.set_input_value("종목코드", "039490")
    kiwoom.set_input_value("기준일자", "20170224")
    kiwoom.set_input_value("수정주가구분", 1)
    kiwoom.comm_rq_data("opt10081_req", "opt10081", 0, "0101")

    while kiwoom.remained_data == True:
        time.sleep(TR_REQ_TIME_INTERVAL)
        kiwoom.set_input_value("종목코드", "039490")
        kiwoom.set_input_value("기준일자", "20170224")
        kiwoom.set_input_value("수정주가구분", 1)
        kiwoom.comm_rq_data("opt10081_req", "opt10081", 2, "0101")

    df = pd.DataFrame(kiwoom.ohlcv, columns=['open', 'high', 'low', 'close', 'volume'], index=kiwoom.ohlcv['date'])

    con = sqlite3.connect("c:/Users/hyunchel/stock.db")
    df.to_sql('039490', con, if_exists='replace')
# Out:
# connected

# %%
import urllib.request
from bs4 import BeautifulSoup
code =['005930']
for c in code:
    url="http://comp.fnguide.com/SVO2/ASP/SVD_Invest.asp?pGB=1&gicode=A" + c + "&cID=&MenuYn=Y&ReportGB=&NewMenuID=105&stkGb=701"
    f = urllib.request.urlopen(url).read()
    soup=BeautifulSoup(f, 'html.parser')
    cells = soup.find('tr', {'id': "p_grid1_10"}).find_all('td')
    for cell in cells:
        print (cell.string)
# Out:
# 5.49
# 5.41
# 6.85
# 6.12

# %%
import urllib.request
from bs4 import BeautifulSoup
code =['005930']
for c in code:
    url="http://comp.fnguide.com/SVO2/ASP/SVD_Invest.asp?pGB=1&gicode=A" + c + "&cID=&MenuYn=Y&ReportGB=&NewMenuID=105&stkGb=701"
    f = urllib.request.urlopen(url).read()
    soup=BeautifulSoup(f, 'html.parser')
    print (soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <link href="/svo2/css/compeach.css?_=201701171422" rel="stylesheet">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta charset="utf-8">
# <meta content="width=device-width" name="viewport">
# <!-- <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"> -->
# <script src="../js/lib/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="../js/comp_load.js" type="text/javascript"></script>
# <script src="../js/lib/jquery.autocomplete.js" type="text/javascript"></script>
# <link href="../css/jquery.autocomplete.css" rel="stylesheet" type="text/css"/>
# <link href="/SVO2/img/CompanyGuide.ico" rel="SHORTCUT ICON">
# <script src="../js/autocomplete.js" type="text/javascript"></script>
# <meta content="" name="author">
# <meta content="" name="description">
# <title>삼성전자(A005930) | 투자지표 | 기업정보 | Company Guide</title>
# </meta></meta></link></meta></meta></meta></link></head>
# <body class="">
# <div id="skip_navi">
# <a href="#compBody" onclick="document.getElementById('compBody').tabIndex=-1;document.getElementById('compBody').focus();return false;">본문 바로가기</a>
# <a href="#compGnb" onclick="document.getElementById('compGnb').tabIndex=-1;document.getElementById('compGnb').focus();return false;">메뉴 바로가기</a>
# </div>
# <script>
# 	function ToggleRow(strID) {
# 		var obj = document.getElementsByName('Parent_Tr_' + strID);
# 		if (document.getElementById('Parent_Imag_' + strID).src.indexOf('plus') > -1) //현재 + 표시
# 		{
# 			document.getElementById('Parent_Imag_' + strID).src = '../Images/icon_minus.png';
# 			document.getElementById('Parent_Imag_' + strID).alt = '상세 내용 닫기';
# 			for (i = 0; i < obj.length; i++)
# 			{
# 				obj[i].style.display = '';
# 			}
# 		} else {
# 			document.getElementById('Parent_Imag_' + strID).src = '../Images/icon_plus.png';
# 			document.getElementById('Parent_Imag_' + strID).alt = '상세 내용 열기';
# 			for (i = 0; i < obj.length; i++)
# 			{
# 				obj[i].style.display = 'none';
# 			}
# 		}
# 	}
#
# 	function ToggleReportGB(reporgGb){
# 		document.getElementById('ReportGb').value = reporgGb;
# 		GoMenu(document.getElementById('NewMenuID').value);
# 	}
#
# 	function chartHide(gb){
# 		if (gb == 'H'){
# 			$('.chartHide').hide();
# 			$('.chartShow').show();
# 			$('.ul_col2_l').hide();
# 			$('.ul_col2_r').hide();
# 		}else{
# 			$('.chartHide').show();
# 			$('.chartShow').hide();
# 			$('.ul_col2_l').show();
# 			$('.ul_col2_r').show();
# 		}
#
# 	}
#
#
# </script>
# <div class="fng_body ">
# <div class="fng_wrap">
# <div class="headwrap">
# <div class="headertop">
# <h1><a href="/SVO2/asp/SVD_Main.asp"><span>상장기업분석</span></a></h1>
# <div class="hdt_rgt">
# <form method="get" name="frmMain">
# <div class="input_ty1 lk_in">
# <input id="SearchText" title="정확한 종목명 또는 종목코드 입력(잘모를 경우 다음 종목찾기 링크 이용)" type="text"/>
# <input id="gicode" type="hidden" value="A005930"/>
# <input id="giname" type="hidden" value="삼성전자"/>
# <input id="stkGb" type="hidden" value="701"/>
# <input id="NewMenuID" type="hidden" value="105"/>
# <input id="pGb" type="hidden" value="1"/>
# <input id="cID" type="hidden" value=""/>
# <input id="ReportGb" type="hidden" value="D"/>
# <input id="MenuYn" type="hidden" value="Y"/>
# <input id="strResearchYN" type="hidden" value=""/>
# <a class="btn_lookup" href="javascript:void(0)" title="종목검색팝업 새창열기"><span class="htxt">열기</span></a>
# </div>
# <!--
#                             <a href="javascript:void(0)" class="btn_ty2">조회</a>
#                             -->
# <a class="btn_ty1" href="javascript:GoPrint();"><span>인쇄</span></a>
# </form>
# </div>
# </div>
# <div class="headergnb" id="compGnb">
# <ul class="gnb_dp1wrap">
# <li class="gnb_dp1 gnb_ac">
# <!-- SVD_Invest.asp -->
# <!-- SVD_Main.asp -->
# <a class="dp1a" href="javascript:GoMenu('101',null,false)">기업정보</a>
# <ul class="gnb_dp2wrap gnb_n1">
# <li class="gnb_dp2 gnb_dp2_start">
# <a href="javascript:GoMenu('101')">Snapshot</a>
# <a href="javascript:GoMenu('102')">기업개요</a>
# <a href="javascript:GoMenu('103')">재무제표</a>
# <a href="javascript:GoMenu('104')">재무비율</a>
# <a class="ac" href="javascript:GoMenu('105')">투자지표</a>
# <a href="javascript:GoMenu('108')">컨센서스</a>
# </li>
# <li class="gnb_dp2">
# <a href="javascript:GoMenu('109')">지분분석</a>
# <a href="javascript:GoMenu('110')">업종분석</a>
# <a href="javascript:GoMenu('106')">경쟁사비교</a>
# <a href="javascript:GoMenu('107')">거래소공시</a>
# <a href="javascript:GoMenu('111')">금감원공시</a>
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- etf_snapshot.asp -->
# <a class="dp1a" href="javascript:GoMenu('401',null,false)">ETF/ETN 정보</a>
# <ul class="gnb_dp2wrap gnb_n2">
# <li class="gnb_dp2 gnb_dp2_start">
# <a href="javascript:GoMenu('401')">ETF Snapshot</a>
# <a href="javascript:GoMenu('402')">성과 및 위험분석</a>
# <a href="javascript:GoMenu('403')">ETN Snapshot</a>
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_Report_Trend.asp -->
# <a class="dp1a" href="javascript:GoMenu('801',null,false)">리포트</a>
# <ul class="gnb_dp2wrap gnb_n3">
# <li class="gnb_dp2 gnb_dp2_start">
# <a href="javascript:GoMenu('801')">리포트동향</a>
# <a href="javascript:GoMenu('901')">요약리포트</a>
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_ProResultCorp.asp -->
# <a class="dp1a" href="javascript:GoMenu('503',null,false)">실적속보</a>
# <ul class="gnb_dp2wrap gnb_n4">
# <li class="gnb_dp2 gnb_dp2_start">
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_SortByTargetPrc.asp -->
# <a class="dp1a" href="javascript:GoMenu('201',null,false)">컨센서스 스크리닝</a>
# <ul class="gnb_dp2wrap gnb_n5">
# <li class="gnb_dp2 gnb_dp2_start">
# <a href="javascript:GoMenu('201')">목표주가 괴리율</a>
# <a href="javascript:GoMenu('202')">컨센서스 상/하향 비율</a>
# <a href="javascript:GoMenu('203')">어닝서프라이즈</a>
# <a href="javascript:GoMenu('204')">턴어라운드</a>
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_UJRank.asp -->
# <a class="dp1a" href="javascript:GoMenu('301',null,false)">랭킹 분석</a>
# <ul class="gnb_dp2wrap gnb_n6">
# <li class="gnb_dp2 gnb_dp2_start">
# <a href="javascript:GoMenu('301')">업종별 순위</a>
# <a href="javascript:GoMenu('302')">지표별 순위</a>
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_comp_calendar.asp -->
# <a class="dp1a" href="javascript:GoMenu('701',null,false)">캘린더</a>
# <ul class="gnb_dp2wrap gnb_n7">
# <li class="gnb_dp2 gnb_dp2_start">
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_CreditScore.asp -->
# <a class="dp1a" href="javascript:GoMenu('501',null,false)">부가정보</a>
# <ul class="gnb_dp2wrap gnb_n8">
# <li class="gnb_dp2 gnb_dp2_start">
# <a href="javascript:GoMenu('501')">신용등급</a>
# <a href="javascript:GoMenu('502')">기업주소록</a>
# </li>
# </ul>
# </li>
# <li class="gnb_dp1">
# <!-- SVD_Invest.asp -->
# <!-- SVD_Help10.asp -->
# <a class="dp1a" href="javascript:GoMenu('601',null,false)">이용안내</a>
# <ul class="gnb_dp2wrap gnb_n9">
# <li class="gnb_dp2 gnb_dp2_start">
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <!-- GNB -->
# <div class="contwrap" id="compBody"><!-- 컨텐츠 페이지 구성은 섹션으로 구성됨  -->
# <!-- 공통기업개요 -->
# <!-- 공통기업개요 -->
# <div class="section ul_corpinfo">
# <div class="corp_group1">
# <h1 id="giName">삼성전자</h1>
# <h2>005930</h2>
# <span class="etc1">|</span>
# <!--
# 					<h3>SamsungElec</h3>
# 					<span class="etc1">&#124;</span>
# 					-->
# <a class="btn_shome" href="http://www.samsung.com/sec" id="btn_shome" target="_blank"><span>홈페이지</span></a>
# <dl id="dl_btn_shome" style="display:none;"><dt>홈페이지</dt><dd id="dd_btn_shome">http://www.samsung.com/sec</dd></dl>
# <a class="btn_sphone" href="javascript:void(0)" id="btn_sphone"><span>전화번호</span></a>
# <dl id="dl_btn_sphone" style="display:none;"><dt>전화번호</dt><dd id="dd_btn_sphone">031-200-1114 | IR 담당자 02-2255-8137</dd></dl>
# <a class="btn_spmap" href="javascript:void(0)" id="btn_spmap"><span>주소</span></a>
# <dl id="dl_btn_spmap" style="display:none;"><dt>주소</dt><dd id="dd_btn_spmap">경기도 수원시 영통구 삼성로 129 (매탄동)</dd></dl>
# <p class="stxt_group">
# <span class="stxt stxt1">KSE  코스피 전기,전자</span>
# <span id="strMarketTxt" style="display:none">코스피 전기,전자</span>
# <span class="etc2">|</span>
# <span class="stxt stxt2">FICS  휴대폰 및 관련부품</span>
# <span class="etc2">|</span>
# <span class="stxt stxt3">12월 결산</span>
# </p>
# </div>
# <div class="corp_group2" id="corp_group2">
# <dl>
# <dt>
# <dl style="display:none;"><dt>PER(Price Earning Ratio)</dt><dd>전일자 보통주 수정주가 / 최근 결산 EPS(주당순이익) <br>* EPS = 당기순이익 / 수정평균발행주식수<br>* 최근결산은 2017/12 (연간) 기준임.</br></br></dd></dl>
# <a class="tip_in" href="javascript:void(0)" id="h_per">PER</a>
# </dt>
# <dd>7.65</dd>
# </dl>
# <dl>
# <dt>
# <dl style="display:none;"><dt>12M PER</dt><dd>전일자 보통주 수정주가 / 12개월 Forward EPS</dd></dl>
# <a class="tip_in" href="javascript:void(0)" id="h_12m">12M PER</a>
# </dt>
# <dd>6.21</dd>
# </dl>
# <dl>
# <dt>
# <dl style="display:none;"><dt>업종 PER</dt><dd>시장대표업종||SUM(구성종목 시가총액)/SUM(구성종목 당기순이익)<br>* 전일자 보통주 시가총액 기준<br>* 당기순이익은  최근결산 2017/12 (연간) 기준임.</br></br></dd></dl>
# <a class="tip_in" href="javascript:void(0)" id="h_u_per"><span class="ko">업종</span> PER</a>
# </dt>
# <dd>6.51</dd>
# </dl>
# <dl>
# <dt>
# <dl style="display:none;"><dt>PBR(Price Book-value Ratio)</dt><dd>전일자 보통주 수정주가 / 최근 결산기 BPS(주당순자산) <br>* BPS=(지배주주지분-자기주식) / 무상조정기말주식수(우선주 및 자사주 포함) <br>* 최근결산은 2017/12 (연간) 기준임.</br></br></dd></dl>
# <a class="tip_in" href="javascript:void(0)" id="h_pbr">PBR</a>
# </dt>
# <dd>1.43</dd>
# </dl>
# <dl>
# <dt>
# <dl style="display:none;"><dt>배당수익률</dt><dd>{최근 결산기 보통주 DPS(현금, 무상조정) / 전일자 보통주 수정주가} *100<br>* 최근결산은 2017/12 (연간) 기준임.</br></dd></dl>
# <a class="tip_in" href="javascript:void(0)" id="h_rate"><span class="ko">배당수익률</span></a>
# </dt>
# <dd>2.05%</dd>
# </dl>
# </div>
# </div>
# <div class="section ul_de">
# <!-- 데이터 없음 -->
# <div class="ul_wrap">
# <div class="ul_tab_ty1">
# <div class="btline">
# <div class="um_gbtn tab_ty grd_ty1">
# <a class="gbtn_f r3 ac" href="javascript:;">연결</a>
# <a class="gbtn_e r3" href="SVD_Invest.asp?pGB=1&amp;gicode=A005930&amp;cID=&amp;MenuYn=Y&amp;ReportGB=B&amp;NewMenuID=105&amp;stkGb=701">별도</a>
# </div>
# <div class="btns_rgt">
# <a class="us_btn chartHide" href="javascript:chartHide('H');" style="display:block;"><span class="img"></span>차트 감추기</a>
# <a class="us_btn chartShow" href="javascript:chartHide('S');" style="display:none;"><span class="img"></span>차트 보이기</a>
# </div>
# </div>
# </div>
# </div>
# <!--**************** 차트 테이블 시작 ******************-->
# <!-- Per Share 지표 , Multiple 지표 -->
# <div class="ul_col2wrap">
# <div class="ul_col2_l">
# <div class="ul_wrap">
# <div class="um_topbar bmshadow">
# <div class="topbar_wrap">
# <div class="topbar_lft">
# <h2>Per Share 지표</h2>
# </div>
# <div class="topbar_rgt">
# <span class="txt1">단위 : 원</span>
# </div>
# </div>
# </div>
# <div class="um_chart chart_ht1">
# <div class="chart_wrap">
# <a class="chartdatapop" href="javascript:openGridPopup('div1_img');" title="클릭:차트데이터 새창열림"><img alt="최근 4개년 연간 Per Share 지표: 자세한 내용은 클릭후 팝업창 참고" id="div1_img" onerror="this.src='/SVO/Handbook_New/images/nodata.png'" src="/SVO2/chartImg/05_01/A005930_D_D_05_01.png"/></a>
# </div>
# </div>
# </div>
# </div>
# <div class="ul_col2_r">
# <div class="ul_wrap">
# <div class="um_topbar bmshadow">
# <div class="topbar_wrap">
# <div class="topbar_lft">
# <h2>Multiple 지표</h2>
# </div>
# <div class="topbar_rgt">
# <span class="txt1">단위 : 배</span>
# </div>
# </div>
# </div>
# <div class="um_chart chart_ht1">
# <div class="chart_wrap">
# <a class="chartdatapop" href="javascript:openGridPopup('div2_img');" title="클릭:차트데이터 새창열림"><img alt="최근 4개년 연간 Multiple 지표: 자세한 내용은 클릭후 팝업창 참고" id="div2_img" onerror="this.src='/SVO/Handbook_New/images/nodata.png'" src="/SVO2/chartImg/05_02/A005930_D_D_05_02.png"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--**************** 차트 테이블 끝 ******************-->
# <!--**************** 주가관련 지표 시작 ******************-->
# <!-- 주가관련 지표  -->
# <div class="ul_wrap">
# <div class="um_topbar botbd_n bmshadow">
# <div class="topbar_wrap">
# <div class="topbar_lft">
# <h2>주가관련 지표</h2>
# </div>
# <div class="topbar_rgt">
# <span class="txt1">단위 : 억원, 배</span>
# </div>
# </div>
# </div>
# <div class="um_table">
# <table class="us_table_ty1 h_fix ">
# <caption class="cphidden">주가관련 지표</caption>
# <colgroup>
# <col style="width: 8%;">
# <col>
# <col>
# <col>
# <col>
# <col>
# <col>
# <col>
# <col>
# <col>
# <col>
# </col></col></col></col></col></col></col></col></col></col></col></colgroup>
# <thead>
# <tr class="th2row_f">
# <th class="clf tbold" rowspan="2" scope="col">IFRS 연결</th>
# <th colspan="2" scope="col">2014/12</th>
# <th colspan="2" scope="col">2015/12</th>
# <th colspan="2" scope="col">2016/12</th>
# <th colspan="2" scope="col">2017/12</th>
# <th class="cle" colspan="2" scope="col">2018/09</th>
# </tr>
# <tr>
# <th scope="col">최고</th>
# <th scope="col">최저</th>
# <th scope="col">최고</th>
# <th scope="col">최저</th>
# <th scope="col">최고</th>
# <th scope="col">최저</th>
# <th scope="col">최고</th>
# <th scope="col">최저</th>
# <th scope="col">최고</th>
# <th class="cle" scope="col">최저</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="clf l" scope="row"><div>주가<span class="csize">(원)</span></div></th>
# <td class="r">29,400</td>
# <td class="r">21,660</td>
# <td class="r">30,060</td>
# <td class="r">21,340</td>
# <td class="r">36,240</td>
# <td class="r">22,520</td>
# <td class="r">57,220</td>
# <td class="r">35,560</td>
# <td class="r tdbg_y">53,000</td>
# <td class="cle r tdbg_y">43,850</td>
# </tr>
# <tr>
# <th class="clf l" scope="row"><div>시가총액</div></th>
# <td class="r">2,427,885</td>
# <td class="r">1,793,218</td>
# <td class="r">2,471,470</td>
# <td class="r">1,759,146</td>
# <td class="r">2,844,093</td>
# <td class="r">1,842,478</td>
# <td class="r">4,142,750</td>
# <td class="r">2,791,338</td>
# <td class="r tdbg_y">3,786,284</td>
# <td class="cle r tdbg_y">3,140,632</td>
# </tr>
# <tr>
# <th class="clf l" scope="row"><div>PER</div></th>
# <td class="r">10.83</td>
# <td class="r">7.98</td>
# <td class="r">13.68</td>
# <td class="r">9.71</td>
# <td class="r">13.25</td>
# <td class="r">8.23</td>
# <td class="r">10.55</td>
# <td class="r">6.56</td>
# <td class="r tdbg_y"> </td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr>
# <th class="clf l" scope="row"><div>PBR</div></th>
# <td class="r">1.47</td>
# <td class="r">1.08</td>
# <td class="r">1.37</td>
# <td class="r">0.97</td>
# <td class="r">1.49</td>
# <td class="r">0.93</td>
# <td class="r">1.98</td>
# <td class="r">1.23</td>
# <td class="r tdbg_y">1.62</td>
# <td class="cle r tdbg_y">1.34</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <!--**************** 주가관련 지표 끝 ******************-->
# <!--**************** 배당관련 지표 시작 ******************-->
# <!--**************** 차트 테이블 끝 ******************-->
# <!-- 기업가치 지표  -->
# <div class="ul_col2wrap pd_t25">
# <div class="um_topbar bmshadow">
# <div class="topbar_wrap">
# <div class="topbar_lft">
# <h2>기업가치 지표</h2>
# </div>
# <div class="topbar_rgt">
# <span class="txt1">단위 : 억원, 주, %, 배</span>
# </div>
# </div>
# </div>
# <div class="um_table">
# <table class="us_table_ty1 h_fix zigbg_no">
# <caption class="cphidden">기업가치 지표</caption>
# <colgroup>
# <col style="width: 25%;">
# <col>
# <col>
# <col>
# <col>
# <col>
# </col></col></col></col></col></col></colgroup>
# <thead>
# <tr>
# <th class="clf tbold" scope="col">IFRS 연결</th>
# <th scope="col">2014/12</th>
# <th scope="col">2015/12</th>
# <th scope="col">2016/12</th>
# <th scope="col">2017/12</th>
# <th class="cle" scope="col">2018/09</th>
# </tr>
# </thead>
# <!-- 데이터 들어가는 부분 시작 -->
# <tbody>
# <tr class="tbody_tit">
# <th class="cle" colspan="6" scope="col">Per Share</th>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_1">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>EPS</dt><dd>지배주주순이익 / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   EPS</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_1');" id="grid1_1"><span class="blind" id="span_grid1_1">계산에 참여한 계정 펼치기</span></a><span class="csize">(원)</span></div>
# </th>
# <td class="r ">2,713</td>
# <td class="r ">2,198</td>
# <td class="r ">2,735</td>
# <td class="r ">5,421</td>
# <td class="cle r tdbg_y">4,853</td>
# </tr>
# <tr class="c_grid1_1 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      지배주주순이익</div></th>
# <td class="r ">230,825</td>
# <td class="r ">186,946</td>
# <td class="r ">224,157</td>
# <td class="r ">413,446</td>
# <td class="cle r tdbg_y">355,608</td>
# </tr>
# <tr class="c_grid1_1 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정평균주식수<span class="csize">(천주)</span></div></th>
# <td class="r ">8,506,638</td>
# <td class="r ">8,506,638</td>
# <td class="r ">8,195,226</td>
# <td class="r ">7,626,419</td>
# <td class="cle r tdbg_y">7,327,681</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_2">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>EBITDAPS</dt><dd>EBITDA / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   EBITDAPS</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_2');" id="grid1_2"><span class="blind" id="span_grid1_2">계산에 참여한 계정 펼치기</span></a><span class="csize">(원)</span></div>
# </th>
# <td class="r ">5,064</td>
# <td class="r ">5,566</td>
# <td class="r ">6,095</td>
# <td class="r ">9,934</td>
# <td class="cle r tdbg_y">9,236</td>
# </tr>
# <tr class="c_grid1_2 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>EBITDA</dt><dd>영업이익 + 유무형자산상각비총액</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      EBITDA</span></a></div></th>
# <td class="r ">430,785</td>
# <td class="r ">473,443</td>
# <td class="r ">499,536</td>
# <td class="r ">757,624</td>
# <td class="cle r tdbg_y">676,758</td>
# </tr>
# <tr class="c_grid1_2 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정평균주식수<span class="csize">(천주)</span></div></th>
# <td class="r ">8,506,638</td>
# <td class="r ">8,506,638</td>
# <td class="r ">8,195,226</td>
# <td class="r ">7,626,419</td>
# <td class="cle r tdbg_y">7,327,681</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_3">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>CFPS</dt><dd>현금흐름 / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   CFPS</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_3');" id="grid1_3"><span class="blind" id="span_grid1_3">계산에 참여한 계정 펼치기</span></a><span class="csize">(원)</span></div>
# </th>
# <td class="r ">4,836</td>
# <td class="r ">4,658</td>
# <td class="r ">5,263</td>
# <td class="r ">8,321</td>
# <td class="cle r tdbg_y">7,526</td>
# </tr>
# <tr class="c_grid1_3 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>현금흐름</dt><dd>당기순이익 - 비지배주주순이익 + 감가상각비 + 무형자산상각비</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      현금흐름</span></a></div></th>
# <td class="r ">411,359</td>
# <td class="r ">396,255</td>
# <td class="r ">431,286</td>
# <td class="r ">634,620</td>
# <td class="cle r tdbg_y">551,505</td>
# </tr>
# <tr class="c_grid1_3 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정평균주식수<span class="csize">(천주)</span></div></th>
# <td class="r ">8,506,638</td>
# <td class="r ">8,506,638</td>
# <td class="r ">8,195,226</td>
# <td class="r ">7,626,419</td>
# <td class="cle r tdbg_y">7,327,681</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_4">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>SPS</dt><dd>영업수익 / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   SPS</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_4');" id="grid1_4"><span class="blind" id="span_grid1_4">계산에 참여한 계정 펼치기</span></a><span class="csize">(원)</span></div>
# </th>
# <td class="r ">24,241</td>
# <td class="r ">23,588</td>
# <td class="r ">24,632</td>
# <td class="r ">31,414</td>
# <td class="cle r tdbg_y">25,179</td>
# </tr>
# <tr class="c_grid1_4 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      매출액</div></th>
# <td class="r ">2,062,060</td>
# <td class="r ">2,006,535</td>
# <td class="r ">2,018,667</td>
# <td class="r ">2,395,754</td>
# <td class="cle r tdbg_y">1,845,064</td>
# </tr>
# <tr class="c_grid1_4 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정평균주식수<span class="csize">(천주)</span></div></th>
# <td class="r ">8,506,638</td>
# <td class="r ">8,506,638</td>
# <td class="r ">8,195,226</td>
# <td class="r ">7,626,419</td>
# <td class="cle r tdbg_y">7,327,681</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_5">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>BPS</dt><dd>지배주주순자산(자사주차감전) / 수정기말주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   BPS</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_5');" id="grid1_5"><span class="blind" id="span_grid1_5">계산에 참여한 계정 펼치기</span></a><span class="csize">(원)</span></div>
# </th>
# <td class="r ">20,056</td>
# <td class="r ">21,903</td>
# <td class="r ">24,340</td>
# <td class="r ">28,971</td>
# <td class="cle r tdbg_y">32,685</td>
# </tr>
# <tr class="c_grid1_5 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>지배주주순자산</dt><dd>총자본 - 비지배주주지분 - 자기주식</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      지배주주순자산</span></a></div></th>
# <td class="r ">1,706,110</td>
# <td class="r ">1,863,191</td>
# <td class="r ">1,961,747</td>
# <td class="r ">2,134,416</td>
# <td class="cle r tdbg_y">2,393,515</td>
# </tr>
# <tr class="c_grid1_5 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정기말주식수<span class="csize">(천주)</span></div></th>
# <td class="r ">8,506,638</td>
# <td class="r ">8,506,638</td>
# <td class="r ">8,059,638</td>
# <td class="r ">7,367,454</td>
# <td class="cle r tdbg_y">7,322,954</td>
# </tr>
# <tr class="tbody_tit">
# <th class="cle" colspan="6" scope="col">Dividends</th>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_6">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>DPS(보통주,현금)</dt><dd>DPS(보통주,현금) * 무상조정수정계수(보통주)</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   DPS(보통주,현금)(원)</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_6');" id="grid1_6"><span class="blind" id="span_grid1_6">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">400</td>
# <td class="r ">420</td>
# <td class="r ">570</td>
# <td class="r ">850</td>
# <td class="cle r tdbg_y">1,062</td>
# </tr>
# <tr class="c_grid1_6 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      DPS(보통주,현금)(원)</div></th>
# <td class="r ">20,000</td>
# <td class="r ">21,000</td>
# <td class="r ">28,500</td>
# <td class="r ">42,500</td>
# <td class="cle r tdbg_y">18,408</td>
# </tr>
# <tr class="c_grid1_6 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      무상조정계수<span class="csize">(보통주)</span></div></th>
# <td class="r ">50.00</td>
# <td class="r ">50.00</td>
# <td class="r ">50.00</td>
# <td class="r ">50.00</td>
# <td class="cle r tdbg_y">1.00</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_7">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>DPS(1우선주,현금)</dt><dd>DPS(1우선주,현금) * 무상조정수정계수(우선주)</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   DPS(1우선주,현금)(원)</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_7');" id="grid1_7"><span class="blind" id="span_grid1_7">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">401</td>
# <td class="r ">421</td>
# <td class="r ">571</td>
# <td class="r ">851</td>
# <td class="cle r tdbg_y">1,062</td>
# </tr>
# <tr class="c_grid1_7 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      DPS(1우선주,현금)(원)</div></th>
# <td class="r ">20,050</td>
# <td class="r ">21,050</td>
# <td class="r ">28,550</td>
# <td class="r ">42,550</td>
# <td class="cle r tdbg_y">18,408</td>
# </tr>
# <tr class="c_grid1_7 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      무상조정계수<span class="csize">(우선주)</span></div></th>
# <td class="r ">50.00</td>
# <td class="r ">50.00</td>
# <td class="r ">50.00</td>
# <td class="r ">50.00</td>
# <td class="cle r tdbg_y">1.00</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_8">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>배당성향(현금,%)</dt><dd>(배당금(현금) / 지배주주순이익) * 100</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   배당성향(현금)(%)</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_8');" id="grid1_8"><span class="blind" id="span_grid1_8">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">13.00</td>
# <td class="r ">16.42</td>
# <td class="r ">17.81</td>
# <td class="r ">14.09</td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr class="c_grid1_8 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      배당금(현금)(억원)</div></th>
# <td class="r ">30,000</td>
# <td class="r ">30,687</td>
# <td class="r ">39,919</td>
# <td class="r ">58,263</td>
# <td class="cle r tdbg_y">72,138</td>
# </tr>
# <tr class="c_grid1_8 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      지배주주순이익</div></th>
# <td class="r ">230,825</td>
# <td class="r ">186,946</td>
# <td class="r ">224,157</td>
# <td class="r ">413,446</td>
# <td class="cle r tdbg_y">355,608</td>
# </tr>
# <tr class="tbody_tit">
# <th class="cle" colspan="6" scope="col">Multiples</th>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_9">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>PER</dt><dd>수정주가(보통주) / 수정EPS</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   PER</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_9');" id="grid1_9"><span class="blind" id="span_grid1_9">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">9.78</td>
# <td class="r ">11.47</td>
# <td class="r ">13.18</td>
# <td class="r ">9.40</td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr class="c_grid1_9 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정주가(보통주)(원)</div></th>
# <td class="r ">26,540</td>
# <td class="r ">25,200</td>
# <td class="r ">36,040</td>
# <td class="r ">50,960</td>
# <td class="cle r tdbg_y">46,450</td>
# </tr>
# <tr class="c_grid1_9 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>EPS</dt><dd>지배주주순이익 / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      EPS</span></a><span class="csize">(원)</span></div></th>
# <td class="r ">2,713</td>
# <td class="r ">2,198</td>
# <td class="r ">2,735</td>
# <td class="r ">5,421</td>
# <td class="cle r tdbg_y">4,853</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_10">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>PCR</dt><dd>수정주가(보통주) / 수정CFPS</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   PCR</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_10');" id="grid1_10"><span class="blind" id="span_grid1_10">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">5.49</td>
# <td class="r ">5.41</td>
# <td class="r ">6.85</td>
# <td class="r ">6.12</td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr class="c_grid1_10 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정주가(보통주)(원)</div></th>
# <td class="r ">26,540</td>
# <td class="r ">25,200</td>
# <td class="r ">36,040</td>
# <td class="r ">50,960</td>
# <td class="cle r tdbg_y">46,450</td>
# </tr>
# <tr class="c_grid1_10 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>CFPS</dt><dd>현금흐름 / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      CFPS</span></a><span class="csize">(원)</span></div></th>
# <td class="r ">4,836</td>
# <td class="r ">4,658</td>
# <td class="r ">5,263</td>
# <td class="r ">8,321</td>
# <td class="cle r tdbg_y">7,526</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_11">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>PSR</dt><dd>수정주가(보통주) / 수정SPS</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   PSR</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_11');" id="grid1_11"><span class="blind" id="span_grid1_11">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">1.09</td>
# <td class="r ">1.07</td>
# <td class="r ">1.46</td>
# <td class="r ">1.62</td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr class="c_grid1_11 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정주가(보통주)(원)</div></th>
# <td class="r ">26,540</td>
# <td class="r ">25,200</td>
# <td class="r ">36,040</td>
# <td class="r ">50,960</td>
# <td class="cle r tdbg_y">46,450</td>
# </tr>
# <tr class="c_grid1_11 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>SPS</dt><dd>영업수익 / 수정평균주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      SPS</span></a><span class="csize">(원)</span></div></th>
# <td class="r ">24,241</td>
# <td class="r ">23,588</td>
# <td class="r ">24,632</td>
# <td class="r ">31,414</td>
# <td class="cle r tdbg_y">25,179</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_12">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>PBR</dt><dd>수정주가(보통주) / 수정BPS</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   PBR</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_12');" id="grid1_12"><span class="blind" id="span_grid1_12">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">1.32</td>
# <td class="r ">1.15</td>
# <td class="r ">1.48</td>
# <td class="r ">1.76</td>
# <td class="cle r tdbg_y">1.42</td>
# </tr>
# <tr class="c_grid1_12 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      수정주가(보통주)(원)</div></th>
# <td class="r ">26,540</td>
# <td class="r ">25,200</td>
# <td class="r ">36,040</td>
# <td class="r ">50,960</td>
# <td class="cle r tdbg_y">46,450</td>
# </tr>
# <tr class="c_grid1_12 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>BPS</dt><dd>지배주주순자산(자사주차감전) / 수정기말주식수</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      BPS</span></a><span class="csize">(원)</span></div></th>
# <td class="r ">20,056</td>
# <td class="r ">21,903</td>
# <td class="r ">24,340</td>
# <td class="r ">28,971</td>
# <td class="cle r tdbg_y">32,685</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_13">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>EV/Sales</dt><dd>EV / 매출액(영업수익)</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   EV/Sales</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_13');" id="grid1_13"><span class="blind" id="span_grid1_13">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">1.09</td>
# <td class="r ">1.08</td>
# <td class="r ">1.43</td>
# <td class="r ">1.56</td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr class="c_grid1_13 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>EV</dt><dd>시가총액(비지배주주지분포함) + 순차입부채</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      EV</span></a></div></th>
# <td class="r ">2,250,966</td>
# <td class="r ">2,166,915</td>
# <td class="r ">2,894,386</td>
# <td class="r ">3,743,647</td>
# <td class="cle r tdbg_y">3,400,068</td>
# </tr>
# <tr class="c_grid1_13 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div>      매출액</div></th>
# <td class="r ">2,062,060</td>
# <td class="r ">2,006,535</td>
# <td class="r ">2,018,667</td>
# <td class="r ">2,395,754</td>
# <td class="cle r tdbg_y">1,845,064</td>
# </tr>
# <tr class="rwf acd_dep_start_close" id="p_grid1_14">
# <th class="clf" scope="row">
# <div><dl style="display:none;"><dt>EV/EBITDA</dt><dd>EV / EBITDA</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   EV/EBITDA</span></a><a class="btn_acdopen" href="javascript:foldOpen('grid1_14');" id="grid1_14"><span class="blind" id="span_grid1_14">계산에 참여한 계정 펼치기</span></a></div>
# </th>
# <td class="r ">5.23</td>
# <td class="r ">4.58</td>
# <td class="r ">5.79</td>
# <td class="r ">4.94</td>
# <td class="cle r tdbg_y"> </td>
# </tr>
# <tr class="c_grid1_14 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>EV</dt><dd>시가총액(비지배주주지분포함) + 순차입부채</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      EV</span></a></div></th>
# <td class="r ">2,250,966</td>
# <td class="r ">2,166,915</td>
# <td class="r ">2,894,386</td>
# <td class="r ">3,743,647</td>
# <td class="cle r tdbg_y">3,400,068</td>
# </tr>
# <tr class="c_grid1_14 rwf acd_dep2_sub" style="display:none;">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>EBITDA</dt><dd>영업이익 + 유무형자산상각비총액</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      EBITDA</span></a></div></th>
# <td class="r ">430,785</td>
# <td class="r ">473,443</td>
# <td class="r ">499,536</td>
# <td class="r ">757,624</td>
# <td class="cle r tdbg_y">676,758</td>
# </tr>
# <tr class="tbody_tit">
# <th class="cle" colspan="6" scope="col">FCF</th>
# </tr>
# <tr class="rwf">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>총현금흐름</dt><dd>세후영업이익 + 유무형자산상각비</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   총현금흐름</span></a></div></th>
# <td class="r "> 390,559</td>
# <td class="r "> 403,232</td>
# <td class="r "> 423,491</td>
# <td class="r "> 623,891</td>
# <td class="cle r tdbg_y"> 544,108</td>
# </tr>
# <tr class="rwf">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>세후영업이익</dt><dd>영업이익 * (1 - (유효세율 / 100))</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      세후영업이익</span></a></div></th>
# <td class="r "> 210,025</td>
# <td class="r "> 193,923</td>
# <td class="r "> 216,362</td>
# <td class="r "> 402,717</td>
# <td class="cle r tdbg_y"> 348,211</td>
# </tr>
# <tr class="rwf">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>유무형자산상각비</dt><dd>감가상각비 + 무형자산상각비</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">      유무형자산상각비</span></a></div></th>
# <td class="r "> 180,534</td>
# <td class="r "> 209,309</td>
# <td class="r "> 207,130</td>
# <td class="r "> 221,174</td>
# <td class="cle r tdbg_y"> 195,897</td>
# </tr>
# <tr class="rwf">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>총투자</dt><dd>투하자본의증가 + 유무형자산상각비총액</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   총투자</span></a></div></th>
# <td class="r "> 257,695</td>
# <td class="r "> 286,664</td>
# <td class="r "> 208,997</td>
# <td class="r "> 506,359</td>
# <td class="cle r tdbg_y"> 368,335</td>
# </tr>
# <tr class="rwf">
# <th class="clf" scope="row"><div><dl style="display:none;"><dt>FCFF</dt><dd>총현금흐름 - 총투자</dd></dl><a class="tip_in" href="javascript:void(0)"><span class="txt_acd">   FCFF</span></a></div></th>
# <td class="r "> 132,864</td>
# <td class="r "> 116,568</td>
# <td class="r "> 214,494</td>
# <td class="r "> 117,533</td>
# <td class="cle r tdbg_y"> 175,773</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="um_comment">
# <a class="comment_wrap btn_cm cmhidden" href="javascript:void(0)" onclick="cmView(this)">
# <ul>
# <li>* 자산총액 2조원 미만의 기업은 2013년까지 분기 및 반기 연결재무제표 의무 공시가 유예되므로, 해당 기업의 연결 기준 Net Quarter의 항목은 비어있는 것이 정상입니다.<br>(단, 재무상태표의 경우 4분기 Net Quarter는 공시되는 Annual과 동일함)</br></li>
# </ul>
# <span class="cmtext"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="bootomwrap">
# <div class="ul_bottom">
# <div class="ul_bottomwrap">
# <a class="link_txt" href="http://www.fnguide.com" target="_blank"><span>fnguide.com</span></a>
# <div class="txtbox">
# <p class="txt">FnGuide에서 제공하는 정보는 신뢰할 만한 자료 및 정보로부터 얻어진 것이나 그 정확성이나 완전성을 보장 할 수 없으며, 시간이 경과함에 따라 변경될 수 있습니다. 따라서 정보의 오류, 누락에 대하여 FnGuide 또는FnGuide에 자료를 제공하는 회사에서는 그 결과에 대해 법적인 책임을 지지 않습니다.</p>
# </div>
# <p class="waimg"><span>웹 접근성 우수사이트 인증마크(WA인증마크)</span></p>
# </div>
# </div>
# </div>
# <!-- 툴팁 -->
# <div class="ul_tip_a">
# <i class="arrow_top"></i>
# <dl>
# <dt>제목제목</dt>
# <dd>내용내용내용내용내용내용내용내용</dd>
# </dl>
# </div>
# </div>
# </div>
# </body>
# </html>
